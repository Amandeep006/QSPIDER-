# %% [markdown]
# # Pandas
# #Features of Pandas :
# 1. Importing Datasets --> CSV, EXCEL,SQL ETC
# 2. Data Cleaning
# 3. Size Mutability --> To add or remove the rows or columns
# 4. Reshaping and Pivoting the datasets
# 5. Efficient Manipulation and Extraction.
# 6. Statstical Analysis

# %%
import pandas as pd
import numpy as np
# It is used in two ways 
# 1. Series  2. DataFrame

# %% [markdown]
# # Difference Between Series and Array
# --> Series:-
# 1. Series belongs to Pandas.
# 2. After the complex priority every datatype consider as Object.
# 3. It displays only data as well as index and datatype.
# 4. pd.Series(collection)
#
# --> Array:-
# 1. Array belongs to Numpy.
# 2. After the string priority every datatype consider as Object.
# 3. It displays only data.
# 4. np.array(collection)

# %%
# Series : 
# syntax- var=pd.Series( Collection / Dictionary )

s=pd.Series([5,10,15,20,25])
s=pd.Series([5,10,15,20,25],index=["a","b","c","d","e"]) # we can change the values of index value using index argument.
s=pd.Series([5,10,15,20,25],index=["a","b","c","d","e"],name="Values")
s
# Out:
# a     5
# b    10
# c    15
# d    20
# e    25
# Name: Values, dtype: int64

# %%
d={
    "name":["apple","orange"],
    "price":[12,23]
}

f={
    "Apple":250,
    "Orange":300,
    "Banana":450
}


n=["app","man","gra","oran"]
a=pd.Series(f)
# pd.Series(d)
v=pd.Series(n,index=["a","b","c","d"])
v["d"]
v["a"]
v["a"::]
v["d"::-1]
v[::]
v[::-1]
# Out:
# d    oran
# c     gra
# b     man
# a     app
# dtype: str

# %% [markdown]
# # Difference Between Series and DataFrame
#
# ---> Series:-
# 1.
#
# ---> DataFrame:-
# 1.

# %% [markdown]
# # Loc and iloc
#  loc--> Label based indexing
#  iloc--> Location based indexing
#
# loc --> Label based indexing
#   syntax :
#         var.loc[index] -- > to access single value
#         var.loc[[index1,index2---indexN]]--> to access multiple values
#
# iloc ---> Location based indexing
#   syntax :
#         var.iloc[index] --> to access single value
#         var.iloc[[index1,index2,index3---indexN]] ---> To access multiple values

# %%
n=["app","man","gra","oran"]
a=pd.Series(n)
s=pd.Series(n,index=["a","b","c","d"])

# Loc method 
a.loc[[0,1,3]]
s.loc[["a","c","b","d"]]
a.loc[[1,3]]
s.loc[::-1]
s.loc["a"::2]
a.loc[0::2]
a.loc[::-1]

# iloc method 
a.iloc[0]
a.iloc[2]
a.iloc[[0,1,3,2]]
s.iloc[[3,1,0,2]]
# Out:
# d    oran
# b     man
# a     app
# c     gra
# dtype: str

# %% [markdown]
# # DataFrame

# %%
# DataFrame :  
# Syntax : var=pd.DataFrame(dictionary)

d={
    "Name":["Amandeep","Rahul","Mohan","Pankaj"],
    "ID":[1,3,2,4],
    "Salary":["5lpa","8lpa","3lpa","10lpa"]
}
df=pd.DataFrame(d)
df
# Out:
#        Name  ID Salary
# 0  Amandeep   1   5lpa
# 1     Rahul   3   8lpa
# 2     Mohan   2   3lpa
# 3    Pankaj   4  10lpa

# %%
# To add new column in existing DataFrame.
# Syntax : var["new_col_name"]=[equal number of values which are present in DF ]
df["Job"]=["sales","accountant","analyst","Finance"]
df["Blood_grouo"]=["A+","C+","Z-","L+"]
df
# Out:
#        Name  ID Salary         Job Blood_grouo
# 0  Amandeep   1   5lpa       sales          A+
# 1     Rahul   3   8lpa  accountant          C+
# 2     Mohan   2   3lpa     analyst          Z-
# 3    Pankaj   4  10lpa     Finance          L+

# %%
# To read the csv files.
# Syntax: var.pd.read_csv("file_path"/"file_name")

# Datasets to load 
# 1. Titanic 2. hr_data 3. winwquality 4. amazon_fires 5. Tips

# If you get UnicodeDecodeError---> encoding="ISO-8859-1"/"latin1"

titanic = pd.read_csv("https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/titanic.csv",encoding="ISO-8859-1")
hr_data = pd.read_csv("https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/hr_data.csv")
WineQuality = pd.read_csv("https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/winequalityN.csv")
amazon_fires = pd.read_csv("https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/amazon_fires.csv",encoding="ISO-8859-1")
tips = pd.read_csv("https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/tips.csv")
tips
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
"""
var.head() --> It will display top 5 rows.
var.head(n) ---> It will display top n rows.
var.tail()---> It will display bottom 5 rows.
var.tail(n)---> It will display bottom n rows.
var.info() ---> It will display the overall information about Dataframe.
var.shape() ---> It will return number of rows and columns present in the DF.
var.describe() --> It will return the statistical information about DataFrame, It will work only on numeric columns.
var.describe(include=object) --> It will return the non-statistical information about Dataframe
var.describe(include=all) ---> It will return all the information about Dataframe.


var.sample() ---> It will take a single row as a sample.
var.sample(n) ---> It will take a n no. of row as a sample.
var["column_name].unique() ---> It will return the unique values present in the column.
var["column_name].value_counts() ---> It will return the occurance of unique values.
var.sort_values(by="col_name,ascending=False) ---> It sort the  dataframe according to the given value, ascending =False is used for descending order.
var.columns ---> It will return the column names 
"""

# titanic.info()
# hr_data.info()
# tips.shape
# hr_data.shape
# tips.describe()
# tips.describe(include="object")
tips.sample()
tips.sample(4)
tips["tip"].unique()
tips["tip"].value_counts()
tips.sort_values(by="tip")
tips.columns
# Out:
# Index(['Unnamed: 0', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
#        'size'],
#       dtype='str')

# %%
# Indexing and Slicing on Data
# loc and iloc 

# loc --> label based indexing 
  # 1. var.loc[index] or var.loc[index,"col_name"]
  # 2. var.loc[[index1,index2---indexN]] or var.loc[[index1,index2---indexN],[col1,col2---colN]]
  # 3. var.loc[sv:ev:up]
  # 4. var.loc[sv:ev:up,"col_name"] or var.loc[sv:ev:up,[col1,col2---colN]]


tips.loc[1]
tips.loc[[1,2,4,5]]
tips.loc[1::3]
tips.loc[::-1,["tip","smoker","day"]]

#iloc ---> Location based indexing 
   # 1. var.iloc[index]
   # 2. var.iloc[[index1, index2---indexN]] or var.iloc[[index1,index2---indexN],[col_index1,col_index2----col_indexN]]
   # 3. var.iloc[sv:ev:up]
   # 4. var.iloc[sv:ev:up,[col_index1, col_index2---col_indexN]]
   # 5. var.iloc[sv:ev:up,sv:ev:up]
                # row  slice, calumn slice

tips.iloc[1]
tips.iloc[[1,2,5,9],[1,3,4]] # we are not giving here column name , if you want to take column just give column index value.
tips.iloc[0:8,[1,2,3]]
# Out:
#    total_bill   tip     sex
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male
# 2       21.01  3.50    Male
# 3       23.68  3.31    Male
# 4       24.59  3.61  Female
# 5       25.29  4.71    Male
# 6        8.77  2.00    Male
# 7       26.88  3.12    Male

# %% [markdown]
# # Difference between loc and iloc in DataFrame

# %%
# Aggregation Function : 
# 1. sum() ---> Sum of all the values present in the column
# 2. min() ---> Minimumn value present in the column 
# 3. max() ---> Maximum value present in the column 
# 4. mean() ---> Average value
# 5. mode() ---> most frequent value 
# 6. median() ---> middle value after sorting into ascending 
# 7. count() ---> count of values 

# Syntax to apply aggregation function:
        # var["col_name"].fname()

tips["total_bill"]
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
# titanic 
# hr_data 
# WineQuality 
# amazon_fires 
# tips 

# what it the total revenue in tips dataset.
tips["total_bill"].sum()   


# What is the average age of travellers who were traveling in titanic ?
titanic["age"].mean()   


# what was the highest tip given by customer ?
tips["tip"].max()   


# what is the average number of projects in hr ?
hr_data["number_project"].mean()   


# what is the average wine quality ?
WineQuality["quality"].mean()   


# count of travelers travelling in titanic
titanic["sex"].count()   


# Total number of project in hr
hr_data["number_project"].sum()   


# the number of employees who left the company 
hr_data["left"].sum()   


# Total number traverls who servived.
titanic["survived"].sum()   


# Average pH level of alcohol 
WineQuality["pH"].mean()
# Out:
# np.float64(3.218395499383477)

# %%
# Boolean Filtering 
# Syntax: 
      # var[condition]

# titanic 
# hr_data 
# WineQuality 
# amazon_fires 
# tips 

# print only male sex :
tips[tips["sex"]=="Male"]

# count of females
tips[tips["sex"]=="Female"]["sex"].count()

# Average number of projects of IT department.
hr_data[hr_data["department"]=="IT"]["number_project"].mean()

# number of customers visits on Sunday
tips[tips["day"]=="Sun"]["day"].count()

# # Highest pH level of alcohol for red wine 
WineQuality[WineQuality["type"]=="red"]["pH"].max()

# average age of males who were travelling in titanic survived. 
titanic[(titanic["sex"]=="male") & (titanic["survived"]==1)]["age"].mean()

# count of employees who are working in HR department and getting low salary.
hr_data[(hr_data["department"]=="hr")&(hr_data["salary"]=="low")]["salary"].count()

# Average tip given by customer on saturday dinner.
tips[tips["day"]=="Sat"]["tip"].mean()

# Number of employee who left the company and working in Rand Department 
hr_data[(hr_data["left"]==1)&(hr_data["department"]=="RandD")]["department"].count()

# average age of female who survived 
titanic[(titanic["sex"]=="female")&(titanic["survived"]==1)]["age"].mean()

# number of employees got promotion is last 5 years and working with sales department 
hr_data[(hr_data["promotion_last_5years"]==1)&(hr_data["department"]=="sales")]["department"].count()

# what is the highest density of white wine 
WineQuality[WineQuality["type"]=="white"]["density"].max()

# Employees working in each department 

hr_data["department"].value_counts()

# p=hr_data["department"]
# d={}
# for i in p:
#     d[i]=d.get(i,0)+1

# print(d)
# Out:
# department
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: count, dtype: int64

# %% [markdown]
# # Try at home :
# syntax:
#         var["col_name"].isnull()  --> It will return the null values present in the column.
#         var["col_name"].isna()
#         var["col_name"].notnull()

# %%
tips.isnull().sum()
tips.isna().sum()
tips.notnull().sum()
# Out:
# Unnamed: 0    244
# total_bill    244
# tip           244
# sex           244
# smoker        244
# day           244
# time          244
# size          244
# dtype: int64

# %%
# find the  total number of  null values present in the titanic datasets.
titanic.isnull().sum()
# Out:
# pclass         0
# name           0
# sex            0
# age          263
# sibsp          0
# parch          0
# ticket         0
# fare           1
# cabin       1014
# embarked       2
# survived       0
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
# 1. Renaming the column names.
     # syntax:  var_1={"cold_name":"new_name"}
            #   var.rename(columns=var_1,inplace=True)


"""t={"size":"width"}
tips.rename(columns=t) # temperory rename 
tips.rename(columns=t,inplace=True) # permanent rename"""

amazon_fires
d={"ano":"year",
   "mes":"Months",
   "estado":"State",
   "numero":"number_of_fires",
   "encontro":"date"}
amazon_fires.rename(columns=d,inplace=True)
amazon_fires


# amazon_fires
# Out:
#       year    Months      State number_of_fires      date
# 0     1998   Janeiro       Acre         0 Fires  1/1/1998
# 1     1999   Janeiro       Acre         0 Fires  1/1/1999
# 2     2000   Janeiro       Acre         0 Fires  1/1/2000
# 3     2001   Janeiro       Acre         0 Fires  1/1/2001
# 4     2002   Janeiro       Acre         0 Fires  1/1/2002
# ...    ...       ...        ...             ...       ...
# 6449  2012  Dezembro  Tocantins             128  1/1/2012
# 6450  2013  Dezembro  Tocantins              85  1/1/2013
# 6451  2014  Dezembro  Tocantins             223  1/1/2014
# 6452  2015  Dezembro  Tocantins             373  1/1/2015
# 6453  2016  Dezembro  Tocantins             119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
d={"Name":["Sai","Rahul","Harsh","Yash","Harsh","Divyansh"],
   "ID":[101,102,103,104,103,105],
   "Salary":["5lpa","7lpa","4.5lpa","8lpa","4.5lpa","10lpa"]
   }

df=pd.DataFrame(d)
df
# Out:
#        Name   ID  Salary
# 0       Sai  101    5lpa
# 1     Rahul  102    7lpa
# 2     Harsh  103  4.5lpa
# 3      Yash  104    8lpa
# 4     Harsh  103  4.5lpa
# 5  Divyansh  105   10lpa

# %%
# To find the duplicate rows present in the dataFrame
# syntax:  var.duplicated()
df.duplicated().sum()

# total number of duplicate values present in each dataset.
# tips.duplicated().sum() #0
# titanic.duplicated().sum() #0
# hr_data.duplicated().sum() #0
# WineQuality.duplicated().sum() #1168
# amazon_fires.duplicated().sum() # 30
# Out:
# np.int64(1)

# %%
# To remove duplicate rows from the column.  
# syntax:  var.drop_duplicates(inplace=True)


# amazon_fires.drop_duplicates()

df=df.drop_duplicates()
amazon_fires.drop_duplicates(inplace=True)
WineQuality.drop_duplicates(inplace=True)

# %%
# Resetting the index of DataFrame
# Syntax:   var.reset_index(inplace=True) 
# It reset the index of DataFrame and old index will act as a column.


df.reset_index(inplace=True)
df
# Out:
#    index      Name   ID  Salary
# 0      0       Sai  101    5lpa
# 1      1     Rahul  102    7lpa
# 2      2     Harsh  103  4.5lpa
# 3      3      Yash  104    8lpa
# 4      5  Divyansh  105   10lpa

# %%
# To remove colum from the dataFrame
# Syntax: var.drop("col_name","axis=1",inplace=True)

# df.drop("level_0",axis=1,inplace=True)
# df.drop("index",axis=1,inplace=True)
df
# Out:
#    index      Name   ID  Salary
# 0      0       Sai  101    5lpa
# 1      1     Rahul  102    7lpa
# 2      2     Harsh  103  4.5lpa
# 3      3      Yash  104    8lpa
# 4      5  Divyansh  105   10lpa

# %%
# To remove rows from the DataFrame.

# syntax:  var.drop(var.index[index_num])  
      #              or
      # axis=1  it execute column by column 
      # axis =0 it execute row by row (by default)
      # var.drop(var.index[[index1,index2,-----indexN]])
      # var.drop(var.columns[index_num],axis=1) --> to frop column with the use of index number of column 


# df.drop(df.index[4])
# df.drop(df.index[[1,3,2]])
df.drop(df.columns[1],axis=1)
# Out:
#    index   ID  Salary
# 0      0  101    5lpa
# 1      1  102    7lpa
# 2      2  103  4.5lpa
# 3      3  104    8lpa
# 4      5  105   10lpa

# %%
# To change the data present inside column.
# Syntax:  
     # var1={"old_value":"new_value"}
     # var["col_name"]=var["col_name"].map(var1)
     # Drawback of map function :  
       # 1. if there is a spelling mistake it will change the value into Nan.
       # 2. Compulsary we have to change every unique data present in the column.

d={"white":"white_wine",
   "red":"red_wine"
   }
# WineQuality=WineQuality["type"].map(d)

# WineQuality["type"].unique()
# # WineQuality.columns
# # WineQuality


day={
    "Janeiro":"january",
    "Fevereiro":"february",
    "Março":"March",
    "Abril":"April",
    "Maio":"May",
    "Junho":"June",
    "Julho":"July",
    "Agosto":"August",
    "Setembro":"September",
    "Outubro":"October",
    "Novembro":"November",
    "Dezembro":"December"
    
}

# amazon_fires["Months"].value_counts()
# amazon_fires["Months"]=amazon_fires["Months"].map(day)
amazon_fires["Months"].unique()
# Out:
# <StringArray>
# [  'january',  'february',     'March',     'April',       'May',      'June',
#       'July',    'August', 'September',   'October',  'November',  'December']
# Length: 12, dtype: str
