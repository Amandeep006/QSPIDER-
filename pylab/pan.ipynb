# %% [markdown]
# # Pandas
# #Features of Pandas :
# 1. Importing Datasets --> CSV, EXCEL,SQL ETC
# 2. Data Cleaning
# 3. Size Mutability --> To add or remove the rows or columns
# 4. Reshaping and Pivoting the datasets
# 5. Efficient Manipulation and Extraction.
# 6. Statstical Analysis

# %%
import pandas as pd
# It is used in two ways 
# 1. Series  2. DataFrame

# %% [markdown]
# # Difference Between Series and Array
# --> Series:-
# 1. Series belongs to Pandas.
# 2. After the complex priority every datatype consider as Object.
# 3. It displays only data as well as index and datatype.
# 4. pd.Series(collection)
#
# --> Array:-
# 1. Array belongs to Numpy.
# 2. After the string priority every datatype consider as Object.
# 3. It displays only data.
# 4. np.array(collection)
