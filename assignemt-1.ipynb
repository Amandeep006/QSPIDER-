# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. WAQTD NAME OF THE EMPLOYEE ALONG WITH THEIR ANNUAL SALARY.

# %%
df=pd.read_csv("EMP_Table.csv")
print(df)
# Out:
#     EMPNO   ENAME        JOB   MGR   HIREDATE   SAL    COMM  DEPTNO
# 0    7369   SMITH      CLERK  7902  17-Dec-80   800     NaN      20
# 1    7499   ALLEN   SALESMAN  7698  20-Feb-81  1600   300.0      30
# 2    7521    WARD   SALESMAN  7698  22-Feb-81  1250   500.0      30
# 3    7566   JONES    MANAGER  7839  02-Apr-81  2975     NaN      20
# 4    7654  MARTIN   SALESMAN  7698  28-Sep-81  1250  1400.0      30
# 5    7698   BLAKE    MANAGER  7839  01-May-81  2850     NaN      30
# 6    7782   CLARK    MANAGER  7839  09-Jun-81  2450     NaN      10
# 7    7788   SCOTT    ANALYST  7566  19-Apr-87  3000     NaN      20
# 8    7839    KING  PRESIDENT     0  17-Nov-81  5000     NaN      10
# 9    7844  TURNER   SALESMAN  7698  08-Sep-81  1500     0.0      30
# 10   7876   ADAMS      CLERK  7788  23-May-87  1100     NaN      20
# 11   7900   JAMES      CLERK  7698  03-Dec-81   950     NaN      30
# 12   7902    FORD    ANALYST  7566  03-Dec-81  3000     NaN      20
# ...

# %%
# Top 5 resords of the table.
print(df.head())
# Out:
#    EMPNO   ENAME       JOB   MGR   HIREDATE   SAL    COMM  DEPTNO
# 0   7369   SMITH     CLERK  7902  17-Dec-80   800     NaN      20
# 1   7499   ALLEN  SALESMAN  7698  20-Feb-81  1600   300.0      30
# 2   7521    WARD  SALESMAN  7698  22-Feb-81  1250   500.0      30
# 3   7566   JONES   MANAGER  7839  02-Apr-81  2975     NaN      20
# 4   7654  MARTIN  SALESMAN  7698  28-Sep-81  1250  1400.0      30

# %%
# WAQTD NAME OF THE EMPLOYEE ALONG WITH THEIR ANNUAL SALARY.
print(df["SAL"]*12)
# Out:
# 0      9600
# 1     19200
# 2     15000
# 3     35700
# 4     15000
# 5     34200
# 6     29400
# 7     36000
# 8     60000
# 9     18000
# 10    13200
# 11    11400
# 12    36000
# 13    15600
# Name: SAL, dtype: int64

# %%
# WAQTD ENAME AND JOB FOR ALL THE EMPLOYEE WITH THEIR HALF TERM SALARY.
df["Half_sal"]=df["SAL"]//2
print(df[["ENAME","Half_sal"]])
# Out:
#      ENAME  Half_sal
# 0    SMITH       400
# 1    ALLEN       800
# 2     WARD       625
# 3    JONES      1487
# 4   MARTIN       625
# 5    BLAKE      1425
# 6    CLARK      1225
# 7    SCOTT      1500
# 8     KING      2500
# 9   TURNER       750
# 10   ADAMS       550
# 11   JAMES       475
# 12    FORD      1500
# 13  MILLER       650

# %% [markdown]
# WAQTD ALL THE DETAILS OF THE EMPLOYEES ALONG WITH ANNUALBOUNUS OF 2000.

# %%
df["ANN_BON"]=df["SAL"]*12+2000
print(df)
# Out:
#     EMPNO   ENAME        JOB   MGR   HIREDATE   SAL    COMM  DEPTNO  Half_sal  \
# 0    7369   SMITH      CLERK  7902  17-Dec-80   800     NaN      20       400
# 1    7499   ALLEN   SALESMAN  7698  20-Feb-81  1600   300.0      30       800
# 2    7521    WARD   SALESMAN  7698  22-Feb-81  1250   500.0      30       625
# 3    7566   JONES    MANAGER  7839  02-Apr-81  2975     NaN      20      1487
# 4    7654  MARTIN   SALESMAN  7698  28-Sep-81  1250  1400.0      30       625
# 5    7698   BLAKE    MANAGER  7839  01-May-81  2850     NaN      30      1425
# 6    7782   CLARK    MANAGER  7839  09-Jun-81  2450     NaN      10      1225
# 7    7788   SCOTT    ANALYST  7566  19-Apr-87  3000     NaN      20      1500
# 8    7839    KING  PRESIDENT     0  17-Nov-81  5000     NaN      10      2500
# 9    7844  TURNER   SALESMAN  7698  08-Sep-81  1500     0.0      30       750
# 10   7876   ADAMS      CLERK  7788  23-May-87  1100     NaN      20       550
# ...

# %% [markdown]
#  4. WAQTD NAME SALARY AND SALARY WITH A HIKE OD 10%.

# %%
df["HIKE"]=df["SAL"]+df["SAL"]*10//100
print(df[["ENAME","SAL","HIKE"]])
# Out:
#      ENAME   SAL  HIKE
# 0    SMITH   800   880
# 1    ALLEN  1600  1760
# 2     WARD  1250  1375
# 3    JONES  2975  3272
# 4   MARTIN  1250  1375
# 5    BLAKE  2850  3135
# 6    CLARK  2450  2695
# 7    SCOTT  3000  3300
# 8     KING  5000  5500
# 9   TURNER  1500  1650
# 10   ADAMS  1100  1210
# 11   JAMES   950  1045
# 12    FORD  3000  3300
# 13  MILLER  1300  1430

# %% [markdown]
# 5. WAQTD NAME SALARY AND SALARY WITH DEDUCTION OF 25%.

# %%
df["DED"]=df["SAL"]-df["SAL"]*25//100
print(df[["ENAME","SAL","DED"]])
# Out:
#      ENAME   SAL   DED
# 0    SMITH   800   600
# 1    ALLEN  1600  1200
# 2     WARD  1250   938
# 3    JONES  2975  2232
# 4   MARTIN  1250   938
# 5    BLAKE  2850  2138
# 6    CLARK  2450  1838
# 7    SCOTT  3000  2250
# 8     KING  5000  3750
# 9   TURNER  1500  1125
# 10   ADAMS  1100   825
# 11   JAMES   950   713
# 12    FORD  3000  2250
# 13  MILLER  1300   975

# %% [markdown]
#  6.WAQTD NAME ANS SALARY WITH MONTHLY HIKE OF 50.

# %%
df["MH"]=df["SAL"]+df["SAL"]*50//100
print(df[["ENAME","SAL","MH"]])
# Out:
#      ENAME   SAL    MH
# 0    SMITH   800  1200
# 1    ALLEN  1600  2400
# 2     WARD  1250  1875
# 3    JONES  2975  4462
# 4   MARTIN  1250  1875
# 5    BLAKE  2850  4275
# 6    CLARK  2450  3675
# 7    SCOTT  3000  4500
# 8     KING  5000  7500
# 9   TURNER  1500  2250
# 10   ADAMS  1100  1650
# 11   JAMES   950  1425
# 12    FORD  3000  4500
# 13  MILLER  1300  1950

# %% [markdown]
# 7. WAQTD NAME AND DESIGNATION ALONG WITH 100 PENALTY IN SALARY.

# %%
df["PNT"]=df["SAL"]-100
print(df[["ENAME","JOB","PNT"]])
# Out:
#      ENAME        JOB   PNT
# 0    SMITH      CLERK   700
# 1    ALLEN   SALESMAN  1500
# 2     WARD   SALESMAN  1150
# 3    JONES    MANAGER  2875
# 4   MARTIN   SALESMAN  1150
# 5    BLAKE    MANAGER  2750
# 6    CLARK    MANAGER  2350
# 7    SCOTT    ANALYST  2900
# 8     KING  PRESIDENT  4900
# 9   TURNER   SALESMAN  1400
# 10   ADAMS      CLERK  1000
# 11   JAMES      CLERK   850
# 12    FORD    ANALYST  2900
# 13  MILLER      CLERK  1200

# %% [markdown]
# 8. WAQTD NAME OF THE EMPLOYEE WORKING AS CLERK.

# %%
print(df[df["JOB"]=="CLERK"])
# Out:
#     EMPNO   ENAME    JOB   MGR   HIREDATE   SAL  COMM  DEPTNO  Half_sal  \
# 0    7369   SMITH  CLERK  7902  17-Dec-80   800   NaN      20       400
# 10   7876   ADAMS  CLERK  7788  23-May-87  1100   NaN      20       550
# 11   7900   JAMES  CLERK  7698  03-Dec-81   950   NaN      30       475
# 13   7934  MILLER  CLERK  7782  23-Jan-82  1300   NaN      10       650
#
#     ANN_BON  HIKE  DED    MH   PNT
# 0     11600   880  600  1200   700
# 10    15200  1210  825  1650  1000
# 11    13400  1045  713  1425   850
# 13    17600  1430  975  1950  1200

# %% [markdown]
# 9. WAQTD SLARY OF THE EMPLOYEE EARNS MORE THAN 2000.

# %%
print(df[df["SAL"]>2000])
# Out:
#     EMPNO  ENAME        JOB   MGR   HIREDATE   SAL  COMM  DEPTNO  Half_sal  \
# 3    7566  JONES    MANAGER  7839  02-Apr-81  2975   NaN      20      1487
# 5    7698  BLAKE    MANAGER  7839  01-May-81  2850   NaN      30      1425
# 6    7782  CLARK    MANAGER  7839  09-Jun-81  2450   NaN      10      1225
# 7    7788  SCOTT    ANALYST  7566  19-Apr-87  3000   NaN      20      1500
# 8    7839   KING  PRESIDENT     0  17-Nov-81  5000   NaN      10      2500
# 12   7902   FORD    ANALYST  7566  03-Dec-81  3000   NaN      20      1500
#
#     ANN_BON  HIKE   DED    MH   PNT
# 3     37700  3272  2232  4462  2875
# 5     36200  3135  2138  4275  2750
# 6     31400  2695  1838  3675  2350
# 7     38000  3300  2250  4500  2900
# 8     62000  5500  3750  7500  4900
# 12    38000  3300  2250  4500  2900

# %% [markdown]
# 10. WAQTD DETAILS OF THE  EMP WHO NAME IS JONES.

# %%
print(df[df["ENAME"]=="JONES"])
# Out:
#    EMPNO  ENAME      JOB   MGR   HIREDATE   SAL  COMM  DEPTNO  Half_sal  \
# 3   7566  JONES  MANAGER  7839  02-Apr-81  2975   NaN      20      1487
#
#    ANN_BON  HIKE   DED    MH   PNT
# 3    37700  3272  2232  4462  2875

# %% [markdown]
# 11. WAQTD  NAME AND SAL ALONG WITH HIS ANNUAL SALARY IF THE ANNUAL SALARY IS MORE THAN 1200.

# %%
df["ANN_SAL"]=df["SAL"]*12
print(df["ANN_SAL"])
# Out:
# 0      9600
# 1     19200
# 2     15000
# 3     35700
# 4     15000
# 5     34200
# 6     29400
# 7     36000
# 8     60000
# 9     18000
# 10    13200
# 11    11400
# 12    36000
# 13    15600
# Name: ANN_SAL, dtype: int64

# %% [markdown]
# 12. WAQTD EMPNO. OF THE EMPLOYEES WHO ARE WORKING IN DEPT 30.

# %%
print(df[df["DEPTNO"]==30])
# Out:
#     EMPNO   ENAME       JOB   MGR   HIREDATE   SAL    COMM  DEPTNO
# 1    7499   ALLEN  SALESMAN  7698  20-Feb-81  1600   300.0      30
# 2    7521    WARD  SALESMAN  7698  22-Feb-81  1250   500.0      30
# 4    7654  MARTIN  SALESMAN  7698  28-Sep-81  1250  1400.0      30
# 5    7698   BLAKE   MANAGER  7839  01-May-81  2850     NaN      30
# 9    7844  TURNER  SALESMAN  7698  08-Sep-81  1500     0.0      30
# 11   7900   JAMES     CLERK  7698  03-Dec-81   950     NaN      30

# %% [markdown]
# 13. WAQTD NAME AND SALARY GIVEN TO AN EMPLOYEE IF EMPLOYEE EARNS A COMMISSION OF RUPEES 1400.

# %%
print(df[["ENAME","SAL"]])
# Out:
#      ENAME   SAL
# 0    SMITH   800
# 1    ALLEN  1600
# 2     WARD  1250
# 3    JONES  2975
# 4   MARTIN  1250
# 5    BLAKE  2850
# 6    CLARK  2450
# 7    SCOTT  3000
# 8     KING  5000
# 9   TURNER  1500
# 10   ADAMS  1100
# 11   JAMES   950
# 12    FORD  3000
# 13  MILLER  1300

# %%
print(df[["ENAME","SAL"]&(df["COMM"]==1400)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(df[["ENAME","SAL"]& (df["COMM"]==1400)])
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\arraylike.py:76, in OpsMixin.__rand__(self, other)
#      74 @unpack_zerodim_and_defer("__rand__")
#      75 def __rand__(self, other):
# ---> 76     return self._logical_method(other, roperator.rand_)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\series.py:6746, in Series._logical_method(self, other, op)
#    6743 lvalues = self._values
# ...
